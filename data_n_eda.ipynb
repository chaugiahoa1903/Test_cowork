# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
HDFS_ROOT   = "hdfs://localhost:9000/user/hadoop/rossmann"
OUTPUT_PATH = f"{HDFS_ROOT}/clean/df_clean.parquet"
